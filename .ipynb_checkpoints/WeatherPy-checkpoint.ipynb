# %% [markdown]
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# * See [Example Solution](WeatherPy_Example.pdf) for a reference on expected format.

# %%
# Dependencies 
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from config import api_key
from citipy import citipy


# csv file from citipy
city_file = "worldcities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Store url and unit for API call
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# make a df of the file and take a look at it
cities_df = pd.read_csv(city_file)
cities_df.head()
# Out:
#    Unnamed: 0        City Country    Lat   Temp  Humidity   Wind  Cloudiness
# 0           0   carnarvon      ZA -30.97  64.66        31   2.73           0
# 1           1    buchanan      LR   5.88  80.27        97   6.42          76
# 2           2        brae      GB  60.40  38.41       100  14.99          20
# 3           3  bredasdorp      ZA -34.53  68.13        88   2.24           0
# 4           4    klaksvik      FO  62.23  33.80        80   2.24           0

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.001, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.001, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 589

# %%
# Print random json response for reference of where to find lat,temp,humidity,clouds

# rand_response = requests.get(query_url + "atibaia").json()
# rand_response

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Query URL for API calls
query_url = "{}appid={}&units={}&q=".format(base_url,api_key,units)

# Start list to store dictionaries for each city
weather_data=[]


print("Beginning Calls")
print("-------------------------")
# Start counter for number of calls
i = 0
for city in cities:
    i+=1
    try:
        print("City number {} | {}".format(i, city))
        response = requests.get(query_url + city).json()
        weather_data.append({
            "City":city,
            "Country":response["sys"]["country"],
            "Lat":response["coord"]["lat"],
            "Temp":response['main']['temp'],
            "Humidity":response["main"]["humidity"],
            "Cloudiness":response["clouds"]["all"],
            "Wind Speed":response["wind"]["speed"]
        })
    except Exception as e:
        print("City not found")
# Out:
# Beginning Calls
# -------------------------
# City number 1 | bluff
# City number 2 | akyab
# City not found
# City number 3 | sao filipe
# City number 4 | paris
# City number 5 | kodiak
# City number 6 | ikalamavony
# City number 7 | barentsburg
# City not found
# City number 8 | san patricio
# City number 9 | hilo
# City number 10 | talnakh
# City number 11 | osypenko
# City number 12 | jamestown
# City number 13 | hithadhoo
# City number 14 | santa isabel do rio negro
# City number 15 | takoradi
# City number 16 | bredasdorp
# City number 17 | mys shmidta
# City not found
# City number 18 | zlatoustovsk
# City not found
# City number 19 | cherskiy
# City number 20 | dikson
# City number 21 | busselton
# City number 22 | pringsewu
# City number 23 | kazalinsk
# City not found
# City number 24 | monduli
# City number 25 | puerto ayora
# City number 26 | port alfred
# City number 27 | kruisfontein
# City number 28 | dharchula
# City number 29 | tasiilaq
# City number 30 | atar
# City number 31 | hofn
# City number 32 | punta arenas
# City number 33 | adolfo lopez mateos
# City number 34 | kilindoni
# City number 35 | nanortalik
# City number 36 | ushuaia
# City number 37 | roebourne
# City number 38 | albany
# City number 39 | lyubim
# City number 40 | rikitea
# City number 41 | tiksi
# City number 42 | qaanaaq
# City number 43 | tessalit
# City number 44 | new norfolk
# City number 45 | carnarvon
# City number 46 | kudahuvadhoo
# City number 47 | hermanus
# City number 48 | vaini
# City number 49 | oranjemund
# City number 50 | vostok
# City number 51 | butaritari
# City number 52 | san policarpo
# City number 53 | udachnyy
# City number 54 | barrow
# City number 55 | port elizabeth
# City number 56 | roma
# City number 57 | pagudpud
# City number 58 | thinadhoo
# City number 59 | iqaluit
# City number 60 | moba
# City number 61 | yellowknife
# City number 62 | alofi
# City number 63 | illoqqortoormiut
# City not found
# City number 64 | poykovskiy
# City number 65 | atuona
# City number 66 | halifax
# City number 67 | codrington
# City number 68 | avarua
# City number 69 | yaan
# City number 70 | osa
# City number 71 | bom jesus
# City number 72 | lompoc
# City number 73 | vanimo
# City number 74 | sitka
# City number 75 | beyneu
# City number 76 | buraydah
# City number 77 | nome
# City number 78 | cape town
# City number 79 | chuy
# City number 80 | tuktoyaktuk
# City number 81 | lavrentiya
# City number 82 | kavali
# City number 83 | olafsvik
# City not found
# City number 84 | xinqing
# City number 85 | taolanaro
# City not found
# City number 86 | oussouye
# City number 87 | kapaa
# City number 88 | nizhneyansk
# City not found
# City number 89 | thompson
# City number 90 | lebu
# City number 91 | bubaque
# City number 92 | port hardy
# City number 93 | saint-philippe
# City number 94 | pavia
# City number 95 | mataura
# City number 96 | smoky lake
# City number 97 | dunmore town
# City number 98 | nikolskoye
# City number 99 | wuhu
# City number 100 | homer
# City number 101 | hambantota
# City number 102 | sampit
# City number 103 | tual
# City number 104 | mokhsogollokh
# City number 105 | ouallam
# City number 106 | chokurdakh
# City number 107 | vilyuysk
# City number 108 | gainesville
# City number 109 | bethel
# City number 110 | amderma
# City not found
# City number 111 | yurla
# City number 112 | grindavik
# City number 113 | moron
# City number 114 | saint-georges
# City number 115 | souillac
# City number 116 | ibajay
# City number 117 | okha
# City number 118 | njombe
# City number 119 | haines junction
# City number 120 | kalmunai
# City number 121 | kushmurun
# City not found
# City number 122 | voyvozh
# City number 123 | coquimbo
# City number 124 | lata
# City number 125 | tsihombe
# City not found
# City number 126 | yar-sale
# City number 127 | lakatoro
# City number 128 | proletarsk
# City number 129 | san cristobal
# City number 130 | vestmannaeyjar
# City number 131 | vytegra
# City number 132 | torbay
# City number 133 | lafayette
# City number 134 | onega
# City number 135 | nagapattinam
# City number 136 | castro
# City number 137 | victoria
# City number 138 | saskylakh
# City number 139 | tingo maria
# City number 140 | ponta do sol
# City number 141 | artyk
# City not found
# City number 142 | attawapiskat
# City not found
# City number 143 | clyde river
# City number 144 | bambous virieux
# City number 145 | pevek
# City number 146 | axim
# City number 147 | katangli
# City number 148 | zhezkazgan
# City number 149 | sola
# City number 150 | mahebourg
# City number 151 | hobyo
# City number 152 | vao
# City number 153 | abasolo
# City number 154 | narsaq
# City number 155 | klaksvik
# City number 156 | wahran
# City not found
# City number 157 | cidreira
# City number 158 | namatanai
# City number 159 | hobart
# City number 160 | mar del plata
# City number 161 | barabai
# City number 162 | puerto escondido
# City number 163 | luangwa
# City number 164 | wagar
# City number 165 | pimentel
# City number 166 | namibe
# City number 167 | slave lake
# City number 168 | saint george
# City number 169 | denpasar
# City number 170 | constitucion
# City number 171 | selyatino
# City number 172 | abrau-dyurso
# City number 173 | malumfashi
# City number 174 | mount gambier
# City number 175 | marrakesh
# City number 176 | kerman
# City number 177 | nguiu
# City not found
# City number 178 | altagracia de orituco
# City number 179 | bajo baudo
# City not found
# City number 180 | chute-aux-outardes
# City number 181 | camacha
# City number 182 | severo-kurilsk
# City number 183 | simpang empat
# City number 184 | atbasar
# City number 185 | maracaibo
# City number 186 | pasighat
# City number 187 | belushya guba
# City not found
# City number 188 | salalah
# City number 189 | cranbrook
# City number 190 | maxixe
# City number 191 | khatanga
# City number 192 | saldanha
# City number 193 | igunga
# City number 194 | kikwit
# City number 195 | maun
# City number 196 | zhoucheng
# City number 197 | noumea
# City number 198 | georgetown
# City number 199 | arraial do cabo
# City number 200 | uyemskiy
# City number 201 | yuncheng
# City number 202 | moussoro
# City number 203 | vaitupu
# City not found
# City number 204 | hailey
# City number 205 | kamenskoye
# City not found
# City number 206 | taoudenni
# City number 207 | vardo
# City number 208 | blyznyuky
# City number 209 | kaitangata
# City number 210 | luderitz
# City number 211 | weligama
# City number 212 | yashan
# City number 213 | harper
# City number 214 | coahuayana
# City number 215 | faanui
# City number 216 | mount isa
# City number 217 | grand river south east
# City not found
# City number 218 | mrirt
# City not found
# City number 219 | saleaula
# City not found
# City number 220 | acari
# City number 221 | muzhi
# City number 222 | lushunkou
# City not found
# City number 223 | isangel
# City number 224 | pyapon
# City number 225 | bengkulu
# City not found
# City number 226 | kuusankoski
# City number 227 | khani
# City number 228 | adwa
# City number 229 | zeya
# City number 230 | gdov
# City number 231 | bima
# City number 232 | dong xoai
# City number 233 | sofiysk
# City not found
# City number 234 | norman wells
# City number 235 | nukus
# City number 236 | araouane
# City number 237 | dabhol
# City number 238 | upernavik
# City number 239 | maiduguri
# City number 240 | vila velha
# City number 241 | bilma
# City number 242 | havoysund
# City number 243 | michigan city
# City number 244 | middletown
# City number 245 | rasshevatskaya
# City number 246 | srandakan
# City number 247 | mangrol
# City number 248 | tambacounda
# City number 249 | mikuni
# City number 250 | samusu
# City not found
# City number 251 | ribeira grande
# City number 252 | ibra
# City number 253 | srednekolymsk
# City number 254 | mergui
# City not found
# City number 255 | fortuna
# City number 256 | bathsheba
# City number 257 | tenenkou
# City number 258 | kamenka
# City number 259 | dujuma
# City not found
# City number 260 | yulara
# City number 261 | jumla
# City number 262 | santa isabel
# City number 263 | bushehr
# City number 264 | geraldton
# City number 265 | turukhansk
# City number 266 | karratha
# City number 267 | meulaboh
# City number 268 | catemaco
# City number 269 | the valley
# City number 270 | fort saint john
# City not found
# City number 271 | birao
# City number 272 | zarubino
# City number 273 | voineasa
# City number 274 | grande-riviere
# City not found
# City number 275 | hazorasp
# City number 276 | effingham
# City number 277 | rohnert park
# City number 278 | ban nahin
# City number 279 | beirut
# City number 280 | huarmey
# City number 281 | east london
# City number 282 | alice springs
# City number 283 | cap malheureux
# City number 284 | tommot
# City number 285 | verkhnevilyuysk
# City number 286 | lagoa
# City number 287 | kyabe
# City number 288 | krasnovishersk
# City number 289 | malwan
# City not found
# City number 290 | kasempa
# City number 291 | ramon
# City number 292 | provideniya
# City number 293 | port lincoln
# City number 294 | ust-uda
# City number 295 | longyearbyen
# City number 296 | atasu
# City number 297 | mayo
# City number 298 | oltu
# City number 299 | marcona
# City not found
# City number 300 | nuevo progreso
# City number 301 | caravelas
# City number 302 | sorong
# City number 303 | cabo san lucas
# City number 304 | san vicente
# City number 305 | paamiut
# City number 306 | ust-kamchatsk
# City not found
# City number 307 | college
# City number 308 | olinda
# City number 309 | tamasopo
# City number 310 | male
# City number 311 | mae hong son
# City number 312 | warri
# City number 313 | gazli
# City number 314 | portland
# City number 315 | sorvag
# City not found
# City number 316 | bobcaygeon
# City number 317 | rudbar
# City not found
# City number 318 | nacala
# City number 319 | mackenzie
# City number 320 | korla
# City not found
# City number 321 | brawley
# City number 322 | catalina
# City number 323 | lasa
# City number 324 | tiarei
# City number 325 | lunenburg
# City number 326 | margate
# City number 327 | bombarral
# City number 328 | yasnyy
# City number 329 | hue
# City number 330 | devonport
# City number 331 | bulawayo
# City number 332 | choucheng
# City not found
# City number 333 | broken hill
# City number 334 | barcelos
# City number 335 | leningradskiy
# City number 336 | villa maria
# City number 337 | walvis bay
# City number 338 | ygatimi
# City number 339 | kavieng
# City number 340 | arman
# City number 341 | hrodna
# City number 342 | nkhata bay
# City number 343 | tanout
# City number 344 | cockburn town
# City number 345 | sentyabrskiy
# City not found
# City number 346 | cam ranh
# City number 347 | tanshui
# City not found
# City number 348 | chateaubelair
# City number 349 | bargal
# City not found
# City number 350 | lakes entrance
# City number 351 | northam
# City number 352 | colchester
# City number 353 | guerrero negro
# City number 354 | port hedland
# City number 355 | veraval
# City number 356 | xining
# City number 357 | soeng sang
# City number 358 | sainte-maxime
# City number 359 | cedar city
# City number 360 | maldonado
# City number 361 | flin flon
# City number 362 | khash
# City number 363 | griffith
# City number 364 | lokosovo
# City number 365 | hualmay
# City number 366 | tecoanapa
# City number 367 | hirara
# City number 368 | tautira
# City number 369 | bandundu
# City number 370 | yatou
# City number 371 | lusambo
# City number 372 | shingu
# City number 373 | palafrugell
# City number 374 | seoul
# City number 375 | labuhan
# City number 376 | los llanos de aridane
# City number 377 | kenai
# City number 378 | sarangani
# City number 379 | itarema
# City number 380 | mount darwin
# City number 381 | saint-pierre
# City number 382 | morondava
# City number 383 | caluquembe
# City number 384 | general roca
# City number 385 | airai
# City number 386 | sangin
# City number 387 | zhanaozen
# City number 388 | killybegs
# City number 389 | andros town
# City number 390 | sarkand
# City number 391 | stornoway
# City not found
# City number 392 | aldama
# City number 393 | selfoss
# City number 394 | mushie
# City number 395 | faya
# City number 396 | abu zabad
# City number 397 | mehamn
# City number 398 | deputatskiy
# City number 399 | nioro
# City number 400 | nabire
# City number 401 | taburi
# City not found
# City number 402 | amapa
# City number 403 | pisco
# City number 404 | mosina
# City number 405 | moctezuma
# City number 406 | padang
# City number 407 | cheyenne
# City number 408 | husavik
# City number 409 | camana
# City not found
# City number 410 | abu dhabi
# City number 411 | kletskaya
# City number 412 | bakau
# City number 413 | ketchikan
# City number 414 | bolungarvik
# City not found
# City number 415 | meyungs
# City not found
# City number 416 | ahipara
# City number 417 | buala
# City number 418 | kavaratti
# City number 419 | arlit
# City number 420 | nouadhibou
# City number 421 | ostersund
# City number 422 | katsuura
# City number 423 | evensk
# City number 424 | zdunska wola
# City number 425 | gambela
# City number 426 | balkanabat
# City number 427 | monrovia
# City number 428 | tignere
# City number 429 | san juan de los lagos
# City number 430 | quatre cocos
# City number 431 | goderich
# City number 432 | flinders
# City number 433 | lincoln
# City number 434 | smirnykh
# City number 435 | shimoda
# City number 436 | candido mendes
# City number 437 | aksarka
# City number 438 | andenes
# City not found
# City number 439 | erzin
# City number 440 | honningsvag
# City number 441 | kathmandu
# City number 442 | russell
# City number 443 | aguimes
# City number 444 | san nicolas
# City number 445 | koluszki
# City number 446 | kahului
# City number 447 | wanning
# City number 448 | sao joao da barra
# City number 449 | stromness
# City number 450 | tilichiki
# City number 451 | ixtapa
# City number 452 | iralaya
# City number 453 | nishihara
# City number 454 | ngukurr
# City not found
# City number 455 | lockhart
# City number 456 | guozhen
# City number 457 | brae
# City number 458 | adrar
# City number 459 | upington
# City number 460 | kirakira
# City number 461 | antofagasta
# City number 462 | mecca
# City number 463 | yumen
# City number 464 | dulovo
# City number 465 | dingle
# City number 466 | shimanovsk
# City number 467 | pangnirtung
# City number 468 | taitung
# City number 469 | el dorado
# City number 470 | karolinka
# City number 471 | marzuq
# City number 472 | zaria
# City number 473 | shemonaikha
# City number 474 | jiuquan
# City number 475 | dali
# City number 476 | bonthe
# City number 477 | guamuchil
# City number 478 | notre-dame-de-gravenchon
# City number 479 | palauig
# City number 480 | maragogi
# City number 481 | burica
# City not found
# City number 482 | vila
# City number 483 | wuwei
# City number 484 | brigantine
# City number 485 | wajima
# City number 486 | abu samrah
# City number 487 | mandalgovi
# City number 488 | tabiauea
# City not found
# City number 489 | ancud
# City number 490 | guayaramerin
# City number 491 | la asuncion
# City number 492 | tabory
# City number 493 | ust-maya
# City number 494 | kirksville
# City number 495 | saint-ambroise
# City number 496 | saint-louis
# City number 497 | hasaki
# City number 498 | kisangani
# City number 499 | sambava
# City number 500 | rawson
# City number 501 | bloemfontein
# City number 502 | kalomo
# City not found
# City number 503 | rabo de peixe
# City number 504 | xuddur
# City number 505 | ruatoria
# City not found
# City number 506 | stawell
# City number 507 | antananarivo
# City number 508 | xuanzhou
# City number 509 | ajdabiya
# City number 510 | parrsboro
# City number 511 | galiwinku
# City not found
# City number 512 | merauke
# City number 513 | potsdam
# City number 514 | egvekinot
# City number 515 | katobu
# City number 516 | kutum
# City number 517 | bukene
# City number 518 | taganak
# City number 519 | kiunga
# City number 520 | ucluelet
# City number 521 | alekseyevsk
# City number 522 | krasnoselkup
# City not found
# City number 523 | bilibino
# City number 524 | baruun-urt
# City number 525 | muros
# City number 526 | vila franca do campo
# City number 527 | salym
# City number 528 | port-gentil
# City number 529 | cairns
# City number 530 | santa luzia
# City number 531 | yeppoon
# City number 532 | kashi
# City not found
# City number 533 | robertson
# City number 534 | logansport
# City number 535 | dourados
# City number 536 | tikhvin
# City number 537 | honiara
# City number 538 | kristiinankaupunki
# City not found
# City number 539 | pokhara
# City number 540 | ostrovnoy
# City number 541 | palmer
# City number 542 | pirot
# City number 543 | letlhakeng
# City number 544 | magadi
# City number 545 | sikonge
# City number 546 | taywarah
# City number 547 | zhigansk
# City number 548 | taltal
# City number 549 | fort nelson
# City number 550 | bury saint edmunds
# City not found
# City number 551 | omboue
# City number 552 | minsk
# City number 553 | mayor pablo lagerenza
# City number 554 | mishkino
# City number 555 | teguldet
# City number 556 | chara
# City number 557 | jupiter
# City number 558 | jiaozuo
# City number 559 | thunder bay
# City number 560 | mogadishu
# City number 561 | salamiyah
# City number 562 | kargasok
# City number 563 | sao miguel do araguaia
# City number 564 | khandyga
# City number 565 | tyukhtet
# City number 566 | te anau
# City number 567 | tabulbah
# City not found
# City number 568 | alihe
# City number 569 | lengshuijiang
# City number 570 | berea
# City number 571 | sur
# City number 572 | sao paulo de olivenca
# City number 573 | point pedro
# City number 574 | tarrega
# City number 575 | savannah bight
# City number 576 | kimbe
# City number 577 | port hueneme
# City number 578 | pombas
# City number 579 | quang ngai
# City number 580 | qasigiannguit
# City number 581 | ahumada
# City not found
# City number 582 | catamarca
# City not found
# City number 583 | daru
# City number 584 | dukat
# City number 585 | tura
# City number 586 | otorohanga
# City number 587 | hervey bay
# City number 588 | trairi
# City number 589 | manavalakurichi

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create df from data collected
df = pd.DataFrame(weather_data)
df = df[["City","Country", "Lat", "Temp", "Humidity", "Wind Speed","Cloudiness"]]
df.head()
# Out:
#           City Country    Lat   Temp  Humidity  Wind Speed  Cloudiness
# 0        bluff      AU -23.58  89.95        47        9.55          44
# 1   sao filipe      CV  14.90  70.01        97       17.72           0
# 2        paris      FR  48.86  48.51        66        6.93           0
# 3       kodiak      US  39.95  10.78        47        9.17           1
# 4  ikalamavony      MG -21.17  67.90        94        2.95          32

# %%
# Save new df to csv file
df.to_csv(city_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# create colormap 'yellow to orange' depending on temperature
# reference: https://www.robotswillkillusall.org/posts/mpl-scatterplot-colorbar.html
cmap = matplotlib.cm.get_cmap('Wistia')
normalize = matplotlib.colors.Normalize(vmin=min(df["Temp"]), vmax=max(df["Temp"]))
colors = [cmap(normalize(value)) for value in df["Temp"]]

# Create plot for Temp vs Lat
plt.scatter(
    df["Lat"],
    df["Temp"],
    marker="o",
    c= colors,
    alpha=1
)

plt.title("Latitude vs. Temperature",fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Temperature in Fahrenheit")
plt.grid(linestyle='--', linewidth=1,alpha=0.5)

# Save image
plt.savefig("lat_temp.png")

# Display plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create colormap with shades of blue depending on humidity
cmap = matplotlib.cm.get_cmap('Blues')
normalize = matplotlib.colors.Normalize(vmin=min(df["Humidity"]), vmax=max(df["Humidity"]))
colors = [cmap(normalize(value)) for value in df["Humidity"]]

# Create plot for Humidity vs Lat
plt.scatter(
    df["Lat"],
    df["Humidity"],
    marker="o",
    c= colors,
    alpha=0.75,
    edgecolors="black"
)

plt.title("Latitude vs. Humidity",fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='--', linewidth=1,alpha=0.5)

# Save image
plt.savefig("lat_humidity.png")

# Display plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Colormap also with shades of blue depending on cloudiness
cmap = matplotlib.cm.get_cmap('Blues')
normalize = matplotlib.colors.Normalize(vmin=min(df["Cloudiness"]), vmax=max(df["Cloudiness"]))
colors = [cmap(normalize(value)) for value in df["Cloudiness"]]

# Create plot for Cloudiness vs Lat
plt.scatter(
    df["Lat"],
    df["Cloudiness"],
    marker="o",
    c= colors,
    alpha=0.75,
    edgecolors="black"
)

plt.title("Latitude vs. Cloudiness",fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(linestyle='--', linewidth=1,alpha=0.5)

# Save image
plt.savefig("lat_cloudiness.png")

# Display plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Colormap also with shades of blue depending on cloudiness
cmap = matplotlib.cm.get_cmap('Blues')
normalize = matplotlib.colors.Normalize(vmin=min(df["Wind Speed"]), vmax=max(df["Wind Speed"]))
colors = [cmap(normalize(value)) for value in df["Wind Speed"]]

# Create plot for Wind Speed vs Lat
plt.scatter(
    df["Lat"],
    df["Wind Speed"],
    marker="o",
    c= colors,
    alpha=0.75,
    edgecolor="black"
)

plt.title("Latitude vs. Wind Speed",fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(linestyle='--', linewidth=1,alpha=0.5)

# Save image
plt.savefig("lat_wind.png")

# Display plot
plt.show()
